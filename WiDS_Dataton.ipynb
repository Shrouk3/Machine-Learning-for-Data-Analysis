# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly

# %%
df = pd.read_csv('C:\\Users\hi\\Downloads\\WiDS Dataton.csv')

# %%
df.head()
# Out:
#    Year_Factor State_Factor building_class  \
# 0            1      State_1     Commercial
# 1            1      State_1     Commercial
# 2            1      State_1     Commercial
# 3            1      State_1     Commercial
# 4            1      State_1     Commercial
#
#                                facility_type  floor_area  year_built  \
# 0               Grocery_store_or_food_market     61242.0      1942.0
# 1  Warehouse_Distribution_or_Shipping_center    274000.0      1955.0
# 2                       Retail_Enclosed_mall    280025.0      1951.0
# 3                  Education_Other_classroom     55325.0      1980.0
# 4                  Warehouse_Nonrefrigerated     66000.0      1985.0
#
#    energy_star_rating  ELEVATION  january_min_temp  january_avg_temp  ...  \
# 0                11.0        2.4                36              50.5  ...
# 1                45.0        1.8                36              50.5  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31107 entries, 0 to 31106
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year_Factor                31107 non-null  int64
#  1   State_Factor               31107 non-null  object
#  2   building_class             31107 non-null  object
#  3   facility_type              31107 non-null  object
#  4   floor_area                 31107 non-null  float64
#  5   year_built                 29614 non-null  float64
#  6   energy_star_rating         14502 non-null  float64
#  7   ELEVATION                  31107 non-null  float64
#  8   january_min_temp           31107 non-null  int64
#  9   january_avg_temp           31107 non-null  float64
#  10  january_max_temp           31107 non-null  int64
#  11  february_min_temp          31107 non-null  int64
#  12  february_avg_temp          31107 non-null  float64
# ...

# %%
df.describe()
# Out:
#         Year_Factor    floor_area    year_built  energy_star_rating  \
# count  31107.000000  3.110700e+04  29614.000000        14502.000000
# mean       3.443952  1.871731e+05   1951.965050           63.296580
# std        1.546936  2.790911e+05     41.628088           27.530835
# min        1.000000  9.430000e+02      0.000000            1.000000
# 25%        2.000000  6.474700e+04   1926.000000           44.000000
# 50%        3.000000  1.003200e+05   1952.000000           70.000000
# 75%        5.000000  1.966765e+05   1979.000000           86.000000
# max        6.000000  6.385382e+06   2015.000000          100.000000
#
#           ELEVATION  january_min_temp  january_avg_temp  january_max_temp  \
# count  31107.000000      31107.000000      31107.000000      31107.000000
# mean      54.695204         11.893625         35.576139         59.881184
# std       80.185588         11.046873          8.346048          7.426185
# ...

# %%
df.shape
# Out:
# (31107, 41)

# %%
# Check for null values
null_counts = df.isnull().sum()
print("Null values in each column:")
print(null_counts[null_counts > 0])
# Out:
# Null values in each column:
# year_built                    1493
# energy_star_rating           16605
# direction_max_wind_speed     19915
# direction_peak_wind_speed    19951
# max_wind_speed               19915
# days_with_fog                18486
# dtype: int64

# %%
plt.figure(figsize=(14, 8))
null_counts[null_counts > 0].sort_values().plot(kind='barh', color='orange')
plt.xlabel("Number of Missing Values")
plt.title("Null Values Count per Column")
plt.show()

# %%
# to draw scatter use float values
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="ELEVATION", y="january_avg_temp", hue="building_class", palette="Set2")
plt.title("January Average Temperature vs. Elevation by Building Class")
plt.xlabel("Elevation")
plt.ylabel("January Average Temperature (°F)")
plt.legend(title="Building Class")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, y="facility_type", order=df['facility_type'].value_counts().index, palette="viridis")
plt.title("Distribution of Facility Types")
plt.xlabel("Count")
plt.ylabel("Facility Type")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df["energy_star_rating"], bins=20,kde = True, color="skyblue")
plt.title("Distribution of Energy Star Ratings")
plt.xlabel("Energy Star Rating")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="days_with_fog", y="site_eui", palette="Blues")
plt.title("Site EUI by Days with Fog")
plt.xlabel("Days with Fog")
plt.ylabel("Site EUI")
plt.show()
